# %%
# make sure you ran workspace\ibm-qiskit-login.py first


print("let's try qiskit")
#https://quantumcomputinguk.org/tutorials/implementing-qram-in-qiskit-with-code
# Out:
# let's try qiskit

# %%
from qiskit import QuantumRegister, ClassicalRegister
from qiskit import QuantumCircuit

q = QuantumRegister(12, 'q')
c = ClassicalRegister(1, 'c')

#circuit = QuantumCircuit(12)
circuit = QuantumCircuit(q,c)

# %%
print(circuit)
# Out:
#
#  q_0:
#
#  q_1:
#
#  q_2:
#
#  q_3:
#
#  q_4:
#
#  q_5:
#
#  q_6:
#
#  q_7:
#
#  q_8:
#
#  q_9:
#
# q_10:
#
# q_11:
#
#  c: 1/

# %%
# Set up six different observables.
from qiskit.quantum_info import SparsePauliOp
 
observables_labels = ["IZ", "IX", "ZI", "XI", "ZZ", "XX", "XX", "XX", "XX", "XX", "XX", "XX"]
observables = [SparsePauliOp(label) for label in observables_labels]

# %%
from qiskit_ibm_runtime import QiskitRuntimeService

service = QiskitRuntimeService()
 
backend = service.least_busy(simulator=False, operational=True)

# %%
### Routing nodes ####
circuit.cx(q[0],q[2])
circuit.x(q[3])
circuit.cx(q[2],q[3])

circuit.ccx(q[1],q[2],q[4])
circuit.cx(q[4],q[2])

circuit.ccx(q[1],q[3],q[5])
circuit.cx(q[5],q[3])

circuit.x(q[11]) #Write mode (read mode if commented)

# %%
### Writing to memory cell ###
circuit.ccx(q[11],q[4],q[9])
circuit.ccx(q[11],q[5],q[8])
circuit.ccx(q[11],q[2],q[7])
circuit.ccx(q[11],q[3],q[6])

circuit.barrier(q)

# %%
### Reading memory cell ###
circuit.ccx(q[4],q[9],q[10])
circuit.ccx(q[5],q[8],q[10])
circuit.ccx(q[2],q[7],q[10])
circuit.ccx(q[3],q[6],q[10])

circuit.barrier(q)
circuit.measure(q[10],c[0]) # Measuring readout qubit

# %%
circuit.draw(output='mpl', filename='QRAM.png')

# %%
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

# Convert to an ISA circuit and layout-mapped observables.
pm = generate_preset_pass_manager(backend=backend, optimization_level=1)
isa_circuit = pm.run(circuit)
 
isa_circuit.draw('mpl', idle_wires=False)

# %%
#job = execute(circuit, backend, shots=100)
#job_monitor(job)

# %%
print(isa_circuit.layout)
# Out:
# TranspileLayout(initial_layout=Layout({
# 4: Qubit(QuantumRegister(12, 'q'), 4),
# 3: Qubit(QuantumRegister(12, 'q'), 1),
# 5: Qubit(QuantumRegister(12, 'q'), 3),
# 15: Qubit(QuantumRegister(12, 'q'), 9),
# 6: Qubit(QuantumRegister(12, 'q'), 2),
# 2: Qubit(QuantumRegister(12, 'q'), 8),
# 22: Qubit(QuantumRegister(12, 'q'), 11),
# 7: Qubit(QuantumRegister(12, 'q'), 0),
# 1: Qubit(QuantumRegister(12, 'q'), 5),
# 21: Qubit(QuantumRegister(12, 'q'), 10),
# 8: Qubit(QuantumRegister(12, 'q'), 7),
# 9: Qubit(QuantumRegister(12, 'q'), 6),
# 0: Qubit(QuantumRegister(115, 'ancilla'), 0),
# 10: Qubit(QuantumRegister(115, 'ancilla'), 1),
# 11: Qubit(QuantumRegister(115, 'ancilla'), 2),
# 12: Qubit(QuantumRegister(115, 'ancilla'), 3),
# 13: Qubit(QuantumRegister(115, 'ancilla'), 4),
# 14: Qubit(QuantumRegister(115, 'ancilla'), 5),
# 16: Qubit(QuantumRegister(115, 'ancilla'), 6),
# 17: Qubit(QuantumRegister(115, 'ancilla'), 7),
# 18: Qubit(QuantumRegister(115, 'ancilla'), 8),
# 19: Qubit(QuantumRegister(115, 'ancilla'), 9),
# 20: Qubit(QuantumRegister(115, 'ancilla'), 10),
# 23: Qubit(QuantumRegister(115, 'ancilla'), 11),
# 24: Qubit(QuantumRegister(115, 'ancilla'), 12),
# 25: Qubit(QuantumRegister(115, 'ancilla'), 13),
# 26: Qubit(QuantumRegister(115, 'ancilla'), 14),
# 27: Qubit(QuantumRegister(115, 'ancilla'), 15),
# 28: Qubit(QuantumRegister(115, 'ancilla'), 16),
# 29: Qubit(QuantumRegister(115, 'ancilla'), 17),
# 30: Qubit(QuantumRegister(115, 'ancilla'), 18),
# 31: Qubit(QuantumRegister(115, 'ancilla'), 19),
# 32: Qubit(QuantumRegister(115, 'ancilla'), 20),
# 33: Qubit(QuantumRegister(115, 'ancilla'), 21),
# 34: Qubit(QuantumRegister(115, 'ancilla'), 22),
# 35: Qubit(QuantumRegister(115, 'ancilla'), 23),
# 36: Qubit(QuantumRegister(115, 'ancilla'), 24),
# 37: Qubit(QuantumRegister(115, 'ancilla'), 25),
# 38: Qubit(QuantumRegister(115, 'ancilla'), 26),
# 39: Qubit(QuantumRegister(115, 'ancilla'), 27),
# 40: Qubit(QuantumRegister(115, 'ancilla'), 28),
# 41: Qubit(QuantumRegister(115, 'ancilla'), 29),
# 42: Qubit(QuantumRegister(115, 'ancilla'), 30),
# 43: Qubit(QuantumRegister(115, 'ancilla'), 31),
# 44: Qubit(QuantumRegister(115, 'ancilla'), 32),
# 45: Qubit(QuantumRegister(115, 'ancilla'), 33),
# 46: Qubit(QuantumRegister(115, 'ancilla'), 34),
# 47: Qubit(QuantumRegister(115, 'ancilla'), 35),
# 48: Qubit(QuantumRegister(115, 'ancilla'), 36),
# 49: Qubit(QuantumRegister(115, 'ancilla'), 37),
# 50: Qubit(QuantumRegister(115, 'ancilla'), 38),
# 51: Qubit(QuantumRegister(115, 'ancilla'), 39),
# 52: Qubit(QuantumRegister(115, 'ancilla'), 40),
# 53: Qubit(QuantumRegister(115, 'ancilla'), 41),
# 54: Qubit(QuantumRegister(115, 'ancilla'), 42),
# 55: Qubit(QuantumRegister(115, 'ancilla'), 43),
# 56: Qubit(QuantumRegister(115, 'ancilla'), 44),
# 57: Qubit(QuantumRegister(115, 'ancilla'), 45),
# 58: Qubit(QuantumRegister(115, 'ancilla'), 46),
# 59: Qubit(QuantumRegister(115, 'ancilla'), 47),
# 60: Qubit(QuantumRegister(115, 'ancilla'), 48),
# 61: Qubit(QuantumRegister(115, 'ancilla'), 49),
# 62: Qubit(QuantumRegister(115, 'ancilla'), 50),
# 63: Qubit(QuantumRegister(115, 'ancilla'), 51),
# 64: Qubit(QuantumRegister(115, 'ancilla'), 52),
# 65: Qubit(QuantumRegister(115, 'ancilla'), 53),
# 66: Qubit(QuantumRegister(115, 'ancilla'), 54),
# 67: Qubit(QuantumRegister(115, 'ancilla'), 55),
# 68: Qubit(QuantumRegister(115, 'ancilla'), 56),
# 69: Qubit(QuantumRegister(115, 'ancilla'), 57),
# 70: Qubit(QuantumRegister(115, 'ancilla'), 58),
# 71: Qubit(QuantumRegister(115, 'ancilla'), 59),
# 72: Qubit(QuantumRegister(115, 'ancilla'), 60),
# 73: Qubit(QuantumRegister(115, 'ancilla'), 61),
# 74: Qubit(QuantumRegister(115, 'ancilla'), 62),
# 75: Qubit(QuantumRegister(115, 'ancilla'), 63),
# 76: Qubit(QuantumRegister(115, 'ancilla'), 64),
# 77: Qubit(QuantumRegister(115, 'ancilla'), 65),
# 78: Qubit(QuantumRegister(115, 'ancilla'), 66),
# 79: Qubit(QuantumRegister(115, 'ancilla'), 67),
# 80: Qubit(QuantumRegister(115, 'ancilla'), 68),
# 81: Qubit(QuantumRegister(115, 'ancilla'), 69),
# 82: Qubit(QuantumRegister(115, 'ancilla'), 70),
# 83: Qubit(QuantumRegister(115, 'ancilla'), 71),
# 84: Qubit(QuantumRegister(115, 'ancilla'), 72),
# 85: Qubit(QuantumRegister(115, 'ancilla'), 73),
# 86: Qubit(QuantumRegister(115, 'ancilla'), 74),
# 87: Qubit(QuantumRegister(115, 'ancilla'), 75),
# 88: Qubit(QuantumRegister(115, 'ancilla'), 76),
# 89: Qubit(QuantumRegister(115, 'ancilla'), 77),
# 90: Qubit(QuantumRegister(115, 'ancilla'), 78),
# 91: Qubit(QuantumRegister(115, 'ancilla'), 79),
# 92: Qubit(QuantumRegister(115, 'ancilla'), 80),
# 93: Qubit(QuantumRegister(115, 'ancilla'), 81),
# 94: Qubit(QuantumRegister(115, 'ancilla'), 82),
# 95: Qubit(QuantumRegister(115, 'ancilla'), 83),
# 96: Qubit(QuantumRegister(115, 'ancilla'), 84),
# 97: Qubit(QuantumRegister(115, 'ancilla'), 85),
# 98: Qubit(QuantumRegister(115, 'ancilla'), 86),
# 99: Qubit(QuantumRegister(115, 'ancilla'), 87),
# 100: Qubit(QuantumRegister(115, 'ancilla'), 88),
# 101: Qubit(QuantumRegister(115, 'ancilla'), 89),
# 102: Qubit(QuantumRegister(115, 'ancilla'), 90),
# 103: Qubit(QuantumRegister(115, 'ancilla'), 91),
# 104: Qubit(QuantumRegister(115, 'ancilla'), 92),
# 105: Qubit(QuantumRegister(115, 'ancilla'), 93),
# 106: Qubit(QuantumRegister(115, 'ancilla'), 94),
# 107: Qubit(QuantumRegister(115, 'ancilla'), 95),
# 108: Qubit(QuantumRegister(115, 'ancilla'), 96),
# 109: Qubit(QuantumRegister(115, 'ancilla'), 97),
# 110: Qubit(QuantumRegister(115, 'ancilla'), 98),
# 111: Qubit(QuantumRegister(115, 'ancilla'), 99),
# 112: Qubit(QuantumRegister(115, 'ancilla'), 100),
# 113: Qubit(QuantumRegister(115, 'ancilla'), 101),
# 114: Qubit(QuantumRegister(115, 'ancilla'), 102),
# 115: Qubit(QuantumRegister(115, 'ancilla'), 103),
# 116: Qubit(QuantumRegister(115, 'ancilla'), 104),
# 117: Qubit(QuantumRegister(115, 'ancilla'), 105),
# 118: Qubit(QuantumRegister(115, 'ancilla'), 106),
# 119: Qubit(QuantumRegister(115, 'ancilla'), 107),
# 120: Qubit(QuantumRegister(115, 'ancilla'), 108),
# 121: Qubit(QuantumRegister(115, 'ancilla'), 109),
# 122: Qubit(QuantumRegister(115, 'ancilla'), 110),
# 123: Qubit(QuantumRegister(115, 'ancilla'), 111),
# 124: Qubit(QuantumRegister(115, 'ancilla'), 112),
# 125: Qubit(QuantumRegister(115, 'ancilla'), 113),
# 126: Qubit(QuantumRegister(115, 'ancilla'), 114)
# }), input_qubit_mapping={Qubit(QuantumRegister(12, 'q'), 0): 0, Qubit(QuantumRegister(12, 'q'), 1): 1, Qubit(QuantumRegister(12, 'q'), 2): 2, Qubit(QuantumRegister(12, 'q'), 3): 3, Qubit(QuantumRegister(12, 'q'), 4): 4, Qubit(QuantumRegister(12, 'q'), 5): 5, Qubit(QuantumRegister(12, 'q'), 6): 6, Qubit(QuantumRegister(12, 'q'), 7): 7, Qubit(QuantumRegister(12, 'q'), 8): 8, Qubit(QuantumRegister(12, 'q'), 9): 9, Qubit(QuantumRegister(12, 'q'), 10): 10, Qubit(QuantumRegister(12, 'q'), 11): 11, Qubit(QuantumRegister(115, 'ancilla'), 0): 12, Qubit(QuantumRegister(115, 'ancilla'), 1): 13, Qubit(QuantumRegister(115, 'ancilla'), 2): 14, Qubit(QuantumRegister(115, 'ancilla'), 3): 15, Qubit(QuantumRegister(115, 'ancilla'), 4): 16, Qubit(QuantumRegister(115, 'ancilla'), 5): 17, Qubit(QuantumRegister(115, 'ancilla'), 6): 18, Qubit(QuantumRegister(115, 'ancilla'), 7): 19, Qubit(QuantumRegister(115, 'ancilla'), 8): 20, Qubit(QuantumRegister(115, 'ancilla'), 9): 21, Qubit(QuantumRegister(115, 'ancilla'), 10): 22, Qubit(QuantumRegister(115, 'ancilla'), 11): 23, Qubit(QuantumRegister(115, 'ancilla'), 12): 24, Qubit(QuantumRegister(115, 'ancilla'), 13): 25, Qubit(QuantumRegister(115, 'ancilla'), 14): 26, Qubit(QuantumRegister(115, 'ancilla'), 15): 27, Qubit(QuantumRegister(115, 'ancilla'), 16): 28, Qubit(QuantumRegister(115, 'ancilla'), 17): 29, Qubit(QuantumRegister(115, 'ancilla'), 18): 30, Qubit(QuantumRegister(115, 'ancilla'), 19): 31, Qubit(QuantumRegister(115, 'ancilla'), 20): 32, Qubit(QuantumRegister(115, 'ancilla'), 21): 33, Qubit(QuantumRegister(115, 'ancilla'), 22): 34, Qubit(QuantumRegister(115, 'ancilla'), 23): 35, Qubit(QuantumRegister(115, 'ancilla'), 24): 36, Qubit(QuantumRegister(115, 'ancilla'), 25): 37, Qubit(QuantumRegister(115, 'ancilla'), 26): 38, Qubit(QuantumRegister(115, 'ancilla'), 27): 39, Qubit(QuantumRegister(115, 'ancilla'), 28): 40, Qubit(QuantumRegister(115, 'ancilla'), 29): 41, Qubit(QuantumRegister(115, 'ancilla'), 30): 42, Qubit(QuantumRegister(115, 'ancilla'), 31): 43, Qubit(QuantumRegister(115, 'ancilla'), 32): 44, Qubit(QuantumRegister(115, 'ancilla'), 33): 45, Qubit(QuantumRegister(115, 'ancilla'), 34): 46, Qubit(QuantumRegister(115, 'ancilla'), 35): 47, Qubit(QuantumRegister(115, 'ancilla'), 36): 48, Qubit(QuantumRegister(115, 'ancilla'), 37): 49, Qubit(QuantumRegister(115, 'ancilla'), 38): 50, Qubit(QuantumRegister(115, 'ancilla'), 39): 51, Qubit(QuantumRegister(115, 'ancilla'), 40): 52, Qubit(QuantumRegister(115, 'ancilla'), 41): 53, Qubit(QuantumRegister(115, 'ancilla'), 42): 54, Qubit(QuantumRegister(115, 'ancilla'), 43): 55, Qubit(QuantumRegister(115, 'ancilla'), 44): 56, Qubit(QuantumRegister(115, 'ancilla'), 45): 57, Qubit(QuantumRegister(115, 'ancilla'), 46): 58, Qubit(QuantumRegister(115, 'ancilla'), 47): 59, Qubit(QuantumRegister(115, 'ancilla'), 48): 60, Qubit(QuantumRegister(115, 'ancilla'), 49): 61, Qubit(QuantumRegister(115, 'ancilla'), 50): 62, Qubit(QuantumRegister(115, 'ancilla'), 51): 63, Qubit(QuantumRegister(115, 'ancilla'), 52): 64, Qubit(QuantumRegister(115, 'ancilla'), 53): 65, Qubit(QuantumRegister(115, 'ancilla'), 54): 66, Qubit(QuantumRegister(115, 'ancilla'), 55): 67, Qubit(QuantumRegister(115, 'ancilla'), 56): 68, Qubit(QuantumRegister(115, 'ancilla'), 57): 69, Qubit(QuantumRegister(115, 'ancilla'), 58): 70, Qubit(QuantumRegister(115, 'ancilla'), 59): 71, Qubit(QuantumRegister(115, 'ancilla'), 60): 72, Qubit(QuantumRegister(115, 'ancilla'), 61): 73, Qubit(QuantumRegister(115, 'ancilla'), 62): 74, Qubit(QuantumRegister(115, 'ancilla'), 63): 75, Qubit(QuantumRegister(115, 'ancilla'), 64): 76, Qubit(QuantumRegister(115, 'ancilla'), 65): 77, Qubit(QuantumRegister(115, 'ancilla'), 66): 78, Qubit(QuantumRegister(115, 'ancilla'), 67): 79, Qubit(QuantumRegister(115, 'ancilla'), 68): 80, Qubit(QuantumRegister(115, 'ancilla'), 69): 81, Qubit(QuantumRegister(115, 'ancilla'), 70): 82, Qubit(QuantumRegister(115, 'ancilla'), 71): 83, Qubit(QuantumRegister(115, 'ancilla'), 72): 84, Qubit(Qua ...
# 0: Qubit(QuantumRegister(127, 'q'), 0),
# 10: Qubit(QuantumRegister(127, 'q'), 10),
# 11: Qubit(QuantumRegister(127, 'q'), 11),
# 12: Qubit(QuantumRegister(127, 'q'), 12),
# 13: Qubit(QuantumRegister(127, 'q'), 13),
# 14: Qubit(QuantumRegister(127, 'q'), 14),
# 16: Qubit(QuantumRegister(127, 'q'), 16),
# 17: Qubit(QuantumRegister(127, 'q'), 17),
# 18: Qubit(QuantumRegister(127, 'q'), 18),
# 19: Qubit(QuantumRegister(127, 'q'), 19),
# 20: Qubit(QuantumRegister(127, 'q'), 20),
# 23: Qubit(QuantumRegister(127, 'q'), 23),
# 24: Qubit(QuantumRegister(127, 'q'), 24),
# 25: Qubit(QuantumRegister(127, 'q'), 25),
# 26: Qubit(QuantumRegister(127, 'q'), 26),
# 3: Qubit(QuantumRegister(127, 'q'), 1),
# 5: Qubit(QuantumRegister(127, 'q'), 21),
# 27: Qubit(QuantumRegister(127, 'q'), 27),
# 28: Qubit(QuantumRegister(127, 'q'), 28),
# 29: Qubit(QuantumRegister(127, 'q'), 29),
# 30: Qubit(QuantumRegister(127, 'q'), 30),
# 31: Qubit(QuantumRegister(127, 'q'), 31),
# 2: Qubit(QuantumRegister(127, 'q'), 2),
# 1: Qubit(QuantumRegister(127, 'q'), 3),
# 22: Qubit(QuantumRegister(127, 'q'), 4),
# 21: Qubit(QuantumRegister(127, 'q'), 15),
# 8: Qubit(QuantumRegister(127, 'q'), 22),
# 32: Qubit(QuantumRegister(127, 'q'), 32),
# 33: Qubit(QuantumRegister(127, 'q'), 33),
# 34: Qubit(QuantumRegister(127, 'q'), 34),
# 35: Qubit(QuantumRegister(127, 'q'), 35),
# 36: Qubit(QuantumRegister(127, 'q'), 36),
# 37: Qubit(QuantumRegister(127, 'q'), 37),
# 38: Qubit(QuantumRegister(127, 'q'), 38),
# 6: Qubit(QuantumRegister(127, 'q'), 5),
# 39: Qubit(QuantumRegister(127, 'q'), 39),
# 40: Qubit(QuantumRegister(127, 'q'), 40),
# 41: Qubit(QuantumRegister(127, 'q'), 41),
# 42: Qubit(QuantumRegister(127, 'q'), 42),
# 43: Qubit(QuantumRegister(127, 'q'), 43),
# 44: Qubit(QuantumRegister(127, 'q'), 44),
# 45: Qubit(QuantumRegister(127, 'q'), 45),
# 46: Qubit(QuantumRegister(127, 'q'), 46),
# 4: Qubit(QuantumRegister(127, 'q'), 6),
# 9: Qubit(QuantumRegister(127, 'q'), 7),
# 15: Qubit(QuantumRegister(127, 'q'), 8),
# 47: Qubit(QuantumRegister(127, 'q'), 47),
# 48: Qubit(QuantumRegister(127, 'q'), 48),
# 49: Qubit(QuantumRegister(127, 'q'), 49),
# 50: Qubit(QuantumRegister(127, 'q'), 50),
# 51: Qubit(QuantumRegister(127, 'q'), 51),
# 52: Qubit(QuantumRegister(127, 'q'), 52),
# 53: Qubit(QuantumRegister(127, 'q'), 53),
# 54: Qubit(QuantumRegister(127, 'q'), 54),
# 7: Qubit(QuantumRegister(127, 'q'), 9),
# 55: Qubit(QuantumRegister(127, 'q'), 55),
# 56: Qubit(QuantumRegister(127, 'q'), 56),
# 57: Qubit(QuantumRegister(127, 'q'), 57),
# 58: Qubit(QuantumRegister(127, 'q'), 58),
# 59: Qubit(QuantumRegister(127, 'q'), 59),
# 60: Qubit(QuantumRegister(127, 'q'), 60),
# 61: Qubit(QuantumRegister(127, 'q'), 61),
# 62: Qubit(QuantumRegister(127, 'q'), 62),
# 63: Qubit(QuantumRegister(127, 'q'), 63),
# 64: Qubit(QuantumRegister(127, 'q'), 64),
# 65: Qubit(QuantumRegister(127, 'q'), 65),
# 66: Qubit(QuantumRegister(127, 'q'), 66),
# 67: Qubit(QuantumRegister(127, 'q'), 67),
# 68: Qubit(QuantumRegister(127, 'q'), 68),
# 69: Qubit(QuantumRegister(127, 'q'), 69),
# 70: Qubit(QuantumRegister(127, 'q'), 70),
# 71: Qubit(QuantumRegister(127, 'q'), 71),
# 72: Qubit(QuantumRegister(127, 'q'), 72),
# 73: Qubit(QuantumRegister(127, 'q'), 73),
# 74: Qubit(QuantumRegister(127, 'q'), 74),
# 75: Qubit(QuantumRegister(127, 'q'), 75),
# 76: Qubit(QuantumRegister(127, 'q'), 76),
# 77: Qubit(QuantumRegister(127, 'q'), 77),
# 78: Qubit(QuantumRegister(127, 'q'), 78),
# 79: Qubit(QuantumRegister(127, 'q'), 79),
# 80: Qubit(QuantumRegister(127, 'q'), 80),
# 81: Qubit(QuantumRegister(127, 'q'), 81),
# 82: Qubit(QuantumRegister(127, 'q'), 82),
# 83: Qubit(QuantumRegister(127, 'q'), 83),
# 84: Qubit(QuantumRegister(127, 'q'), 84),
# 85: Qubit(QuantumRegister(127, 'q'), 85),
# 86: Qubit(QuantumRegister(127, 'q'), 86),
# 87: Qubit(QuantumRegister(127, 'q'), 87),
# 88: Qubit(QuantumRegister(127, 'q'), 88),
# 89: Qubit(QuantumRegister(127, 'q'), 89),
# 90: Qubit(QuantumRegister(127, 'q'), 90),
# 91: Qubit(QuantumRegister(127, 'q'), 91),
# 92: Qubit(QuantumRegister(127, 'q'), 92),
# 93: Qubit(QuantumRegister(127, 'q'), 93),
# 94: Qubit(QuantumRegister(127, 'q'), 94),
# 95: Qubit(QuantumRegister(127, 'q'), 95),
# 96: Qubit(QuantumRegister(127, 'q'), 96),
# 97: Qubit(QuantumRegister(127, 'q'), 97),
# 98: Qubit(QuantumRegister(127, 'q'), 98),
# 99: Qubit(QuantumRegister(127, 'q'), 99),
# 100: Qubit(QuantumRegister(127, 'q'), 100),
# 101: Qubit(QuantumRegister(127, 'q'), 101),
# 102: Qubit(QuantumRegister(127, 'q'), 102),
# 103: Qubit(QuantumRegister(127, 'q'), 103),
# 104: Qubit(QuantumRegister(127, 'q'), 104),
# 105: Qubit(QuantumRegister(127, 'q'), 105),
# 106: Qubit(QuantumRegister(127, 'q'), 106),
# 107: Qubit(QuantumRegister(127, 'q'), 107),
# 108: Qubit(QuantumRegister(127, 'q'), 108),
# 109: Qubit(QuantumRegister(127, 'q'), 109),
# 110: Qubit(QuantumRegister(127, 'q'), 110),
# 111: Qubit(QuantumRegister(127, 'q'), 111),
# 112: Qubit(QuantumRegister(127, 'q'), 112),
# 113: Qubit(QuantumRegister(127, 'q'), 113),
# 114: Qubit(QuantumRegister(127, 'q'), 114),
# 115: Qubit(QuantumRegister(127, 'q'), 115),
# 116: Qubit(QuantumRegister(127, 'q'), 116),
# 117: Qubit(QuantumRegister(127, 'q'), 117),
# 118: Qubit(QuantumRegister(127, 'q'), 118),
# 119: Qubit(QuantumRegister(127, 'q'), 119),
# 120: Qubit(QuantumRegister(127, 'q'), 120),
# 121: Qubit(QuantumRegister(127, 'q'), 121),
# 122: Qubit(QuantumRegister(127, 'q'), 122),
# 123: Qubit(QuantumRegister(127, 'q'), 123),
# 124: Qubit(QuantumRegister(127, 'q'), 124),
# 125: Qubit(QuantumRegister(127, 'q'), 125),
# 126: Qubit(QuantumRegister(127, 'q'), 126)
# }), _input_qubit_count=12, _output_qubit_list=[Qubit(QuantumRegister(127, 'q'), 0), Qubit(QuantumRegister(127, 'q'), 1), Qubit(QuantumRegister(127, 'q'), 2), Qubit(QuantumRegister(127, 'q'), 3), Qubit(QuantumRegister(127, 'q'), 4), Qubit(QuantumRegister(127, 'q'), 5), Qubit(QuantumRegister(127, 'q'), 6), Qubit(QuantumRegister(127, 'q'), 7), Qubit(QuantumRegister(127, 'q'), 8), Qubit(QuantumRegister(127, 'q'), 9), Qubit(QuantumRegister(127, 'q'), 10), Qubit(QuantumRegister(127, 'q'), 11), Qubit(QuantumRegister(127, 'q'), 12), Qubit(QuantumRegister(127, 'q'), 13), Qubit(QuantumRegister(127, 'q'), 14), Qubit(QuantumRegister(127, 'q'), 15), Qubit(QuantumRegister(127, 'q'), 16), Qubit(QuantumRegister(127, 'q'), 17), Qubit(QuantumRegister(127, 'q'), 18), Qubit(QuantumRegister(127, 'q'), 19), Qubit(QuantumRegister(127, 'q'), 20), Qubit(QuantumRegister(127, 'q'), 21), Qubit(QuantumRegister(127, 'q'), 22), Qubit(QuantumRegister(127, 'q'), 23), Qubit(QuantumRegister(127, 'q'), 24), Qubit(QuantumRegister(127, 'q'), 25), Qubit(QuantumRegister(127, 'q'), 26), Qubit(QuantumRegister(127, 'q'), 27), Qubit(QuantumRegister(127, 'q'), 28), Qubit(QuantumRegister(127, 'q'), 29), Qubit(QuantumRegister(127, 'q'), 30), Qubit(QuantumRegister(127, 'q'), 31), Qubit(QuantumRegister(127, 'q'), 32), Qubit(QuantumRegister(127, 'q'), 33), Qubit(QuantumRegister(127, 'q'), 34), Qubit(QuantumRegister(127, 'q'), 35), Qubit(QuantumRegister(127, 'q'), 36), Qubit(QuantumRegister(127, 'q'), 37), Qubit(QuantumRegister(127, 'q'), 38), Qubit(QuantumRegister(127, 'q'), 39), Qubit(QuantumRegister(127, 'q'), 40), Qubit(QuantumRegister(127, 'q'), 41), Qubit(QuantumRegister(127, 'q'), 42), Qubit(QuantumRegister(127, 'q'), 43), Qubit(QuantumRegister(127, 'q'), 44), Qubit(QuantumRegister(127, 'q'), 45), Qubit(QuantumRegister(127, 'q'), 46), Qubit(QuantumRegister(127, 'q'), 47), Qubit(QuantumRegister(127, 'q'), 48), Qubit(QuantumRegister(127, 'q'), 49), Qubit(QuantumRegister(127, 'q'), 50), Qubit(QuantumRegister(127, 'q'), 51), Qubit(QuantumRegister(127, 'q'), 52), Qubit(QuantumRegister(127, 'q'), 53), Qubit(QuantumRegister(127, 'q'), 54), Qubit(QuantumRegister(127, 'q'), 55), Qubit(QuantumRegister(127, 'q'), 56), Qubit(QuantumRegister(127, 'q'), 57), Qubit(QuantumRegister(127, 'q'), 58), Qubit(QuantumRegister(127, 'q'), 59), Qubit(QuantumRegister(127, 'q'), 60), Qubit(QuantumRegister(127, 'q'), 61), Qubit(QuantumRegister(127, 'q'), 62), Qubit(QuantumRegister(127, 'q'), 63), Qubit(QuantumRegister(127, 'q'), 64), Qubit(QuantumRegister(127, 'q'), 65), Qubit(QuantumRegister(127, 'q'), 66), Qubit(QuantumRegister(127, 'q'), 67), Qubit(QuantumRegister(127, 'q'), 68), Qubit(QuantumRegister(127, 'q'), 69), Qubit(QuantumRegister(127, 'q'), 70), Qubit(QuantumRegister(127, 'q'), 71), Qubit(QuantumRegister(127, 'q'), 72), Qubit(QuantumRegister(127, 'q'), 73), Qubit(QuantumRegister(127, 'q'), 74), Qubit(QuantumRegister(127, 'q'), 75), Qubit(QuantumRegister(127, 'q'), 76), Qubit(QuantumRegister(127, 'q'), 77), Qubit(QuantumRegister(127, 'q'), 78), Qubit(QuantumRegister(127, 'q'), 79), Qubit(QuantumRegister(127, 'q'), 80), Qubit(QuantumRegister(127, 'q'), 81), Qubit(QuantumRegister(127, 'q'), 82), Qubit(QuantumRegister(127, 'q'), 83), Qubit(QuantumRegister(127, 'q'), 84), Qubit(QuantumRegister(127, 'q'), 85), Qubit(QuantumRegister(127, 'q'), 86), Qubit(QuantumRegister(127, 'q'), 87), Qubit(QuantumRegister(127, 'q'), 88), Qubit(QuantumRegister(127, 'q'), 89), Qubit(QuantumRegister(127, 'q'), 90), Qubit(QuantumRegister(127, 'q'), 91), Qubit(QuantumRegister(127, 'q'), 92), Qubit(QuantumRegister(127, 'q'), 93), Qubit(QuantumRegister(127, 'q'), 94), Qubit(QuantumRegister(127, 'q'), 95), Qubit(QuantumRegister(127, 'q'), 96), Qubit(QuantumRegister(127, 'q'), 97), Qubit(QuantumRegister(127, 'q'), 98), Qubit(QuantumRegister(127, 'q'), 99), Qubit(QuantumRegister(127, 'q'), 100), Qubit(QuantumRegister(127, 'q'), 101), Qubit(QuantumRegister(127, 'q'), 102), Qubit(QuantumRegister(127, 'q'), 103), Qubit(Q ...

# %%
print(observables)
# Out:
# [SparsePauliOp(['IZ'],
#               coeffs=[1.+0.j]), SparsePauliOp(['IX'],
#               coeffs=[1.+0.j]), SparsePauliOp(['ZI'],
#               coeffs=[1.+0.j]), SparsePauliOp(['XI'],
#               coeffs=[1.+0.j]), SparsePauliOp(['ZZ'],
#               coeffs=[1.+0.j]), SparsePauliOp(['XX'],
#               coeffs=[1.+0.j]), SparsePauliOp(['XX'],
#               coeffs=[1.+0.j]), SparsePauliOp(['XX'],
#               coeffs=[1.+0.j]), SparsePauliOp(['XX'],
#               coeffs=[1.+0.j]), SparsePauliOp(['XX'],
#               coeffs=[1.+0.j]), SparsePauliOp(['XX'],
#               coeffs=[1.+0.j]), SparsePauliOp(['XX'],
#               coeffs=[1.+0.j])]

# %%
# Construct the Estimator instance.
from qiskit_ibm_runtime import EstimatorV2 as Estimator
 
estimator = Estimator(backend=backend)
estimator.options.resilience_level = 1
estimator.options.default_shots = 100
 
mapped_observables = [
    observable.apply_layout(isa_circuit.layout) for observable in observables
]
# Out:
# ---------------------------------------------------------------------------
# QiskitError                               Traceback (most recent call last)
# Cell In[14], line 8
#       5 estimator.options.resilience_level = 1
#       6 estimator.options.default_shots = 100
# ----> 8 mapped_observables = [
#       9     observable.apply_layout(isa_circuit.layout) for observable in observables
#      10 ]
#      12 # One pub, with one circuit to run against five different observables.
#      13 job = estimator.run([(isa_circuit, mapped_observables)])
#
# Cell In[14], line 9, in <listcomp>(.0)
#       5 estimator.options.resilience_level = 1
#       6 estimator.options.default_shots = 100
#       8 mapped_observables = [
# ----> 9     observable.apply_layout(isa_circuit.layout) for observable in observables
#      10 ]
#      12 # One pub, with one circuit to run against five different observables.
#      13 job = estimator.run([(isa_circuit, mapped_observables)])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\qiskit\quantum_info\operators\symplectic\sparse_pauli_op.py:1171, in SparsePauliOp.apply_layout(self, layout, num_qubits)
#    1169     return type(self)(["I" * n_qubits] * self.size, self.coeffs)
#    1170 new_op = type(self)("I" * n_qubits)
# -> 1171 return new_op.compose(self, qargs=layout)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\qiskit\quantum_info\operators\symplectic\sparse_pauli_op.py:328, in SparsePauliOp.compose(self, other, qargs, front)
#     325     other = SparsePauliOp(other)
#     327 # Validate composition dimensions and qargs match
# --> 328 self._op_shape.compose(other._op_shape, qargs, front)
#     330 if qargs is not None:
#     331     x1, z1 = self.paulis.x[:, qargs], self.paulis.z[:, qargs]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\qiskit\quantum_info\operators\op_shape.py:477, in OpShape.compose(self, other, qargs, front)
#     475 ret._num_qargs_r = self._num_qargs_r
#     476 if len(qargs) != other._num_qargs_r:
# --> 477     raise QiskitError(
#     478         "Number of qargs does not match ({} != {})".format(
#     479             len(qargs), other._num_qargs_r
#     480         )
#     481     )
#     482 if self._dims_l or other._dims_l:
#     483     if self.dims_l(qargs) != other.dims_r():
#
# QiskitError: 'Number of qargs does not match (12 != 2)'

# %%
# One pub, with one circuit to run against five different observables.
job = estimator.run([(isa_circuit, mapped_observables)])
 
# Use the job ID to retrieve your job data later
print(f">>> Job ID: {job.job_id()}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 # One pub, with one circuit to run against five different observables.
# ----> 2 job = estimator.run([(isa_circuit, mapped_observables)])
#       4 # Use the job ID to retrieve your job data later
#       5 print(f">>> Job ID: {job.job_id()}")
#
# NameError: name 'mapped_observables' is not defined

# %%
#counts = job.result().get_counts()
#
#print(circuit)
#print(counts)

# %%
# This is the result of the entire submission.  You submitted one Pub,
# so this contains one inner result (and some metadata of its own).
job_result = job.result()
 
# This is the result from our single pub, which had six observables,
# so contains information on all six.
pub_result = job.result()[0]

# %%
# Plot the result
 
from matplotlib import pyplot as plt
 
values = pub_result.data.evs
 
errors = pub_result.data.stds
 
# plotting graph
plt.plot(observables_labels, values, '-o')
plt.xlabel('Observables')
plt.ylabel('Values')
plt.show()
